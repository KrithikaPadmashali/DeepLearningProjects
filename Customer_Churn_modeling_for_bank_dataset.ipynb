# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Churn_Modelling.csv")
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df.drop(["RowNumber","CustomerId","Surname"],inplace=True,axis=1)

# %%
df.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
df.dtypes
# Out:
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
df["Gender"].replace({"Female":1,"Male":0},inplace=True)
# Out:
# /tmp/ipython-input-6-718425798.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Gender"].replace({"Female":1,"Male":0},inplace=True)
# /tmp/ipython-input-6-718425798.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["Gender"].replace({"Female":1,"Male":0},inplace=True)

# %%
df.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France       1   42       2       0.00              1
# 1          608     Spain       1   41       1   83807.86              1
# 2          502    France       1   42       8  159660.80              3
# 3          699    France       1   39       1       0.00              2
# 4          850     Spain       1   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
credict_churn_no=df[df.Exited==0].CreditScore
credict_churn_yes=df[df.Exited==1].CreditScore

plt.xlabel("credit score")
plt.ylabel("Number of customer")
plt.title("Customer Churn Prediction Analysis")
plt.hist([credict_churn_yes,credict_churn_no],rwidth=0.95,color=["orange","pink"],label=["Exited=Yes","Exited=No"])
plt.legend()

# %%
balance_churn_no=df[df.Exited==0].Balance
balance_churn_yes=df[df.Exited==1].Balance

plt.xlabel("Balance")
plt.ylabel("Number of customer")
plt.title("Customer Churn Prediction Analysis")
plt.hist([balance_churn_yes,balance_churn_no],rwidth=0.95,color=["orange","pink"],label=["Exited=Yes","Exited=No"])
plt.legend()

# %%
NumOfProducts_churn_no=df[df.Exited==0].NumOfProducts
NumOfProducts_churn_yes=df[df.Exited==1].NumOfProducts

plt.xlabel("NumOfProducts	")
plt.ylabel("Number of customer")
plt.title("Customer Churn Prediction Analysis")
plt.hist([NumOfProducts_churn_yes,NumOfProducts_churn_no],rwidth=0.95,color=["orange","pink"],label=["Exited=Yes","Exited=No"])
plt.legend()
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
EstimatedSalary_churn_no=df[df.Exited==0].EstimatedSalary
EstimatedSalary_churn_yes=df[df.Exited==1].EstimatedSalary

plt.xlabel("EstimatedSalary")
plt.ylabel("Number of customer")
plt.title("Customer Churn Prediction Analysis")
plt.hist([EstimatedSalary_churn_yes,EstimatedSalary_churn_no],rwidth=0.95,color=["orange","pink"],label=["Exited=Yes","Exited=No"])
plt.legend()

# %%
HasCrCard_churn_no=df[df.Exited==0].HasCrCard
HasCrCard_churn_yes=df[df.Exited==1].HasCrCard

plt.xlabel("HasCrCard")
plt.ylabel("Number of customer")
plt.title("Customer Churn Prediction Analysis")
plt.hist([HasCrCard_churn_yes,HasCrCard_churn_no],rwidth=0.95,color=["orange","pink"],label=["Exited=Yes","Exited=No"])
plt.legend()

# %%
IsActiveMember_churn_no=df[df.Exited==0].IsActiveMember
IsActiveMember_churn_yes=df[df.Exited==1].IsActiveMember

plt.xlabel("IsActiveMember")
plt.ylabel("Number of customer")
plt.title("Customer Churn Prediction Analysis")
plt.hist([IsActiveMember_churn_yes,IsActiveMember_churn_no],rwidth=0.95,color=["orange","pink"],label=["Exited=Yes","Exited=No"])
plt.legend()

# %%
	Tenure_churn_no=df[df.Exited==0].	Tenure
	Tenure_churn_yes=df[df.Exited==1].	Tenure

plt.xlabel("	Tenure")
plt.ylabel("Number of customer")
plt.title("Customer Churn Prediction Analysis")
plt.hist([	Tenure_churn_yes,	Tenure_churn_no],rwidth=0.95,color=["orange","pink"],label=["Exited=Yes","Exited=No"])
plt.legend()
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
#Scaling the values to be between 0 and 1
df.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France       1   42       2       0.00              1
# 1          608     Spain       1   41       1   83807.86              1
# 2          502    France       1   42       8  159660.80              3
# 3          699    France       1   39       1       0.00              2
# 4          850     Spain       1   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
cols_to_scale=["CreditScore","Age","Tenure","Balance","NumOfProducts","EstimatedSalary"]
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
df[cols_to_scale]=scaler.fit_transform(df[cols_to_scale])

# %%
df.sample()
# Out:
#       CreditScore Geography  Gender       Age  Tenure   Balance  \
# 6593         0.61   Germany       1  0.162162     0.1  0.331505
#
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 6593       0.333333          1               1         0.921328       0

# %%
df.isnull().sum()
# Out:
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
df1=pd.get_dummies(df,columns=["Geography"],dtype=int)

# %%
df1.head()
# Out:
#    CreditScore  Gender       Age  Tenure   Balance  NumOfProducts  HasCrCard  \
# 0        0.538       1  0.324324     0.2  0.000000       0.000000          1
# 1        0.516       1  0.310811     0.1  0.334031       0.000000          0
# 2        0.304       1  0.324324     0.8  0.636357       0.666667          1
# 3        0.698       1  0.283784     0.1  0.000000       0.333333          0
# 4        1.000       1  0.337838     0.2  0.500246       0.000000          1
#
#    IsActiveMember  EstimatedSalary  Exited  Geography_France  \
# 0               1         0.506735       1                 1
# 1               1         0.562709       0                 0
# 2               0         0.569654       1                 1
# 3               0         0.469120       0                 1
# 4               1         0.395400       0                 0
#
#    Geography_Germany  Geography_Spain
# 0                  0                0
# 1                  0                1
# ...

# %%
for column in df1:
  print(f"{column} : {df1[column].unique()}")
# Out:
# CreditScore : [0.538 0.516 0.304 0.698 1.    0.59  0.944 0.052 0.302 0.668 0.356 0.294
#  0.252 0.398 0.57  0.532 0.606 0.474 0.752 0.764 0.572 0.32  0.638 0.992
#  0.454 0.812 0.442 0.448 0.122 0.482 0.366 0.406 0.34  0.744 0.25  0.28
#  0.908 0.464 0.244 0.23  0.412 0.968 0.62  0.852 0.958 0.574 0.4   0.696
#  0.47  0.876 0.61  0.502 0.612 0.75  0.322 0.528 0.784 0.674 0.41  0.506
#  0.802 0.462 0.77  0.622 0.65  0.776 0.926 0.614 0.508 0.338 0.628 0.656
#  0.814 0.132 0.63  0.854 0.386 0.312 0.286 0.604 0.8   0.758 0.592 0.594
#  0.916 0.348 0.838 0.76  0.33  0.846 0.928 0.72  0.126 0.546 0.64  0.544
#  0.87  0.51  0.258 0.67  0.376 0.424 0.742 0.556 0.636 0.956 0.648 0.55
#  0.164 0.84  0.816 0.89  0.672 0.878 0.478 0.222 0.468 0.458 0.626 0.664
#  0.886 0.682 0.27  0.6   0.808 0.37  0.732 0.378 0.712 0.472 0.562 0.734
#  0.9   0.666 0.708 0.53  0.634 0.268 0.26  0.456 0.324 0.512 0.494 0.856
#  0.328 0.35  0.73  0.46  0.914 0.342 0.818 0.332 0.722 0.536 0.586 0.642
# ...

# %%
X=df1.drop("Exited",axis=1)
y=df1["Exited"]

# %%
from sklearn.model_selection import train_test_split


X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=5,test_size=0.2)

# %%
X_train.shape
# Out:
# (8000, 12)

# %%
X_test.shape
# Out:
# (2000, 12)

# %%
import tensorflow as tf
from tensorflow import keras

model=keras.Sequential([
    keras.layers.Dense(12,input_shape=(12,),activation="relu"),
    keras.layers.Dense(6,activation="relu"),
       keras.layers.Dense(6,activation="relu"),
    keras.layers.Dense(1,activation="sigmoid")
])

model.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=["accuracy"]
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.fit(X_train,y_train,epochs=100)
# Out:
# Epoch 1/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8431 - loss: 0.3725
# Epoch 2/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8437 - loss: 0.3665
# Epoch 3/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8455 - loss: 0.3699
# Epoch 4/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8402 - loss: 0.3719
# Epoch 5/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8427 - loss: 0.3683
# Epoch 6/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8503 - loss: 0.3599
# Epoch 7/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8465 - loss: 0.3617
# Epoch 8/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8437 - loss: 0.3664
# Epoch 9/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8463 - loss: 0.3570
# Epoch 10/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8519 - loss: 0.3464
# Epoch 11/100
# ...

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(patience=10, restore_best_weights=True)

model.fit(X_train, y_train, epochs=200, validation_split=0.2, callbacks=[early_stop])
# Out:
# Epoch 1/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8671 - loss: 0.3346 - val_accuracy: 0.8869 - val_loss: 0.2962
# Epoch 2/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8626 - loss: 0.3358 - val_accuracy: 0.8844 - val_loss: 0.2991
# Epoch 3/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8624 - loss: 0.3235 - val_accuracy: 0.8844 - val_loss: 0.2986
# Epoch 4/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8653 - loss: 0.3255 - val_accuracy: 0.8875 - val_loss: 0.2974
# Epoch 5/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8680 - loss: 0.3172 - val_accuracy: 0.8869 - val_loss: 0.3007
# Epoch 6/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8695 - loss: 0.3211 - val_accuracy: 0.8875 - val_loss: 0.2980
# Epoch 7/200
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8639 - loss: 0.3258 - val_accuracy: 0.8881 - val_loss: 0.2968
# Epoch 8/200
# ...

# %%
model.evaluate(X_test,y_test)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8477 - loss: 0.3549
# [0.3536625802516937, 0.8525000214576721]

# %%
yp=model.predict(X_test)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
yp[:5]
# Out:
# array([[0.05496291],
#        [0.0518847 ],
#        [0.04974639],
#        [0.07607926],
#        [0.05655499]], dtype=float32)

# %%
y_test[:5]
# Out:
# 7054    0
# 442     0
# 3954    0
# 2288    0
# 3196    0
# Name: Exited, dtype: int64

# %%
y_pred=[]
for element in yp:
  if element>0.5:
    y_pred.append(1)
  else:
    y_pred.append(0)

# %%
y_pred[:5]
# Out:
# [0, 0, 0, 0, 0]

# %%
from sklearn.metrics import confusion_matrix,classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.94      0.91      1595
#            1       0.69      0.49      0.57       405
#
#     accuracy                           0.85      2000
#    macro avg       0.79      0.72      0.74      2000
# weighted avg       0.84      0.85      0.84      2000

# %%
import seaborn as sns
cm=tf.math.confusion_matrix(labels=y_test,predictions=y_pred)
sns.heatmap(cm,annot=True,fmt="d")
plt.xlabel("Predicted")
plt.ylabel("Truth")
# Out:
# Text(50.722222222222214, 0.5, 'Truth')

# %%
#Final accuracy
round((1507+198)/(1507+198+88+207),2)
# Out:
# 0.85
